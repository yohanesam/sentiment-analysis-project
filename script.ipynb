# %% [markdown]
# # Sentiment Analysis for Executive Chair
#
# @author :Muhammad Akbar, Yohanes Manullang

# %% [markdown]
# ### Import Library
# First, lets import every libraries we want to use for this experiment.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# After that, let's see whats feature contain in our csv data

# %%
df = pd.read_csv('data.csv', header=0)
df.head()
# Out:
#                      Timestamp                     Nama  \
# 0  2019/04/10 7:18:36 pm GMT+7                    Piput
# 1  2019/04/11 4:46:03 am GMT+7         Uthari Handayani
# 2  2019/04/12 8:22:31 pm GMT+7    Naufal Mahfudz Ismail
# 3  2019/04/12 8:25:59 pm GMT+7          Dwika Nur R. R.
# 4  2019/04/12 8:29:01 pm GMT+7  Salsabilla Haurameuthia
#
#                            Jurusan  Angkatan  No. Handphone (WA)  \
# 0    TEKNIK GRAFIKA DAN PENERBITAN      2018         85777273763
# 1    TEKNIK GRAFIKA DAN PENERBITAN      2018         85692150723
# 2  TEKNIK INFORMATIKA DAN KOMPUTER      2016         81398040451
# 3  TEKNIK INFORMATIKA DAN KOMPUTER      2016         89653033030
# 4                   TEKNIK ELEKTRO      2018         82110278205
#
#   Siapakah namanya ? Siapakah namanya ?.1  \
# 0                 Ya                Tidak
# 1              Iqbal        Anggoro Rizal
# 2     tidak tau wkwk    loh ini sopo wkwk
# 3       Iqbal Fauzan                Rizal
# ...

# %% [markdown]
# as you can see, there is unnamed label. those feature aren't necessary. let's drop it

# %%
datadf.loc[:, :"Berikan alasan kenapa anda memilih opsi tersebut pada pertayaan sebelumnya ?"].head()
# Out:
#                      Timestamp                     Nama  \
# 0  2019/04/10 7:18:36 pm GMT+7                    Piput
# 1  2019/04/11 4:46:03 am GMT+7         Uthari Handayani
# 2  2019/04/12 8:22:31 pm GMT+7    Naufal Mahfudz Ismail
# 3  2019/04/12 8:25:59 pm GMT+7          Dwika Nur R. R.
# 4  2019/04/12 8:29:01 pm GMT+7  Salsabilla Haurameuthia
#
#                            Jurusan  Angkatan  No. Handphone (WA)  \
# 0    TEKNIK GRAFIKA DAN PENERBITAN      2018         85777273763
# 1    TEKNIK GRAFIKA DAN PENERBITAN      2018         85692150723
# 2  TEKNIK INFORMATIKA DAN KOMPUTER      2016         81398040451
# 3  TEKNIK INFORMATIKA DAN KOMPUTER      2016         89653033030
# 4                   TEKNIK ELEKTRO      2018         82110278205
#
#   Siapakah namanya ? Siapakah namanya ?.1  \
# 0                 Ya                Tidak
# 1              Iqbal        Anggoro Rizal
# 2     tidak tau wkwk    loh ini sopo wkwk
# 3       Iqbal Fauzan                Rizal
# ...

# %%
df.dropna()
# Out:
#                        Timestamp                     Nama  \
# 2    2019/04/12 8:22:31 pm GMT+7    Naufal Mahfudz Ismail
# 3    2019/04/12 8:25:59 pm GMT+7          Dwika Nur R. R.
# 4    2019/04/12 8:29:01 pm GMT+7  Salsabilla Haurameuthia
# 6    2019/04/12 8:45:32 pm GMT+7          Faris Ar Rasyid
# 7    2019/04/12 9:07:22 pm GMT+7       Vivi Alfiana Utami
# 8    2019/04/12 9:20:12 pm GMT+7  Muhamad Alvin Sipahutar
# 9    2019/04/12 9:38:47 pm GMT+7           Muhammad Fauzi
# 10  2019/04/12 11:22:08 pm GMT+7                    Dwiza
# 11  2019/04/12 11:44:35 pm GMT+7                M Hudya R
# 12   2019/04/13 5:13:31 am GMT+7               F Nabila P
# 13   2019/04/13 5:19:17 am GMT+7             Faqih mahira
# 14   2019/04/13 8:05:56 am GMT+7    Muhammad Aryo Mujahid
# 15   2019/04/13 9:10:03 am GMT+7     Ari syaifudin arslan
# 16  2019/04/13 10:55:12 am GMT+7              Nathanael R
# 17  2019/04/13 11:08:34 am GMT+7             Deby Shintia
# ...
